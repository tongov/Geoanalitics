# %% [markdown]
# <a href="https://colab.research.google.com/github/tongov/Geoanalitics/blob/main/NEN_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Бот для программы генерации картинок stable diffusion по промпту клиента

# %%
# !pip install diffusers transformers gradio torch -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.5 MB/s eta 0:00:00

# %%
#!pip install accelerate

# %%
#!python nen_bot.py

# %%
import os
import gradio as gr
import torch
from diffusers import StableDiffusionPipeline
from diffusers import EulerDiscreteScheduler
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
import transformers

# %%
transformers.utils.move_cache()
# Out:
# 0it [00:00, ?it/s]

# %%
model = "nen"
token = "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"  # token for nen
#model = "nen100"
#token = "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"  # token for nen100

# %%
# Загрузка модели и планировщика
#model_id = "stabilityai/stable-diffusion-2-1"
model_id = f"Nenmen/{model}"

# %%
os.environ["TOKEN"] = token
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16).to("cuda")
# Out:
# scheduler/scheduler_config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# text_encoder/model.safetensors not found
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/582 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--Nenmen--nen/snapshots/43d75055fe327f326db8b92138f540870fbd2e83/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--Nenmen--nen/snapshots/43d75055fe327f326db8b92138f540870fbd2e83/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--Nenmen--nen/snapshots/43d75055fe327f326db8b92138f540870fbd2e83/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--Nenmen--nen/snapshots/43d75055fe327f326db8b92138f540870fbd2e83/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.

# %%
# Функция для генерации изображения
def generate_image(prompt, num_inference_steps=50, guidance_scale=7.5):
  """
  Генерирует изображение с помощью Stable Diffusion.

  Args:
    prompt: Текстовый запрос для генерации изображения.
    num_inference_steps: Количество шагов инференса.
    guidance_scale: Параметр направляющего масштаба.

  Returns:
    Генерация изображения.
  """
  image = pipe(prompt, num_inference_steps=num_inference_steps, guidance_scale=guidance_scale).images[0]
  return image

# %%
# Создание интерфейса Gradio
iface = gr.Interface(
    fn=generate_image,
    inputs=[
        gr.Textbox(label="Текстовый запрос", lines=1, max_lines=30),
        gr.Slider(label="Количество шагов инференса", minimum=10, maximum=100, step=10, value=50),
        gr.Slider(label="Направляющий масштаб", minimum=1, maximum=15, step=0.5, value=7.5)
    ],
    outputs="image",
    title=f"Генератор изображений Stable Diffusion в стиле {model}",
)

# %%
# Запуск интерфейса
iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://28e106ee2e05cfcac5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://28e106ee2e05cfcac5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#!gradio deploy
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 197, in _main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/typer/main.py", line 703, in wrapper
#     return callback(**use_params)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/cli/commands/deploy_space.py", line 157, in deploy
#     configuration = add_configuration_to_readme(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/cli/commands/deploy_space.py", line 29, in add_configuration_to_readme
#     title = input(f"Enter Spaces app title [{dir_name}]: ") or dir_name
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 210, in _main
#     raise click.Abort() from e
# click.exceptions.Abort
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/gradio", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.10/dist-packages/gradio/cli/cli.py", line 27, in cli
#     app()
#   File "/usr/local/lib/python3.10/dist-packages/typer/main.py", line 321, in __call__
#     return get_command(self)(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 728, in main
#     return _main(
#   File "/usr/local/lib/python3.10/dist-packages/typer/core.py", line 246, in _main
#     rich_utils.rich_abort_error()
#   File "/usr/local/lib/python3.10/dist-packages/typer/rich_utils.py", line 711, in rich_abort_error
#     console.print(ABORTED_TEXT, style=STYLE_ABORTED)
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1684, in print
#     renderables = self._collect_renderables(
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1544, in _collect_renderables
#     self.render_str(
#   File "/usr/local/lib/python3.10/dist-packages/rich/console.py", line 1456, in render_str
#     highlight_text = _highlighter(str(rich_text))
#   File "/usr/local/lib/python3.10/dist-packages/rich/highlighter.py", line 38, in __call__
#     self.highlight(highlight_text)
#   File "/usr/local/lib/python3.10/dist-packages/rich/highlighter.py", line 77, in highlight
#     highlight_regex(re_highlight, style_prefix=self.base_style)
#   File "/usr/local/lib/python3.10/dist-packages/rich/text.py", line 615, in highlight_regex
#     for match in re.finditer(re_highlight, plain):
#   File "/usr/lib/python3.10/re.py", line 247, in finditer
#     return _compile(pattern, flags).finditer(string)
#   File "/usr/lib/python3.10/re.py", line 303, in _compile
#     p = sre_compile.compile(pattern, flags)
#   File "/usr/lib/python3.10/sre_compile.py", line 792, in compile
#     code = _code(p, flags)
#   File "/usr/lib/python3.10/sre_compile.py", line 631, in _code
#     _compile(code, p.data, flags)
#   File "/usr/lib/python3.10/sre_compile.py", line 184, in _compile
#     _compile(code, p, _combine_flags(flags, add_flags, del_flags))
#   File "/usr/lib/python3.10/sre_compile.py", line 158, in _compile
#     emit(REPEAT_ONE)
# KeyboardInterrupt
# ^C

# %%
#!git clone https://huggingface.co/spaces/Nenmen/NenBot
# Out:
# Cloning into 'NenBot'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 1), reused 1 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (9/9), 3.80 KiB | 1.90 MiB/s, done.

# %%
#!git commit -am 'Nenmen/NenBot'
#!git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
